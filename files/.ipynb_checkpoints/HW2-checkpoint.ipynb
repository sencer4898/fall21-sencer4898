# %%
# import required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from scipy.spatial import distance_matrix
from mpl_toolkits.mplot3d import Axes3D

# %%
# Read the data and print first 5 rows

df = pd.read_csv("HW2-data/IE582_Fall21_HW2_q1_data.csv")
df.head()
# Out:
#          X1        X2 class
# 0  0.569483  0.822003     a
# 1  0.411469  0.911424     a
# 2  0.417385 -0.908730     a
# 3 -0.791828  0.610745     a
# 4 -0.806777 -0.590857     a

# %%
# Scatter plot the data.

plt.figure(figsize=(6,6))
sns.scatterplot(x="X1",y="X2", hue="class", style="class", data=df);

# %% [markdown]
# ### a) Apply PCA and Visualize

# %%
# Apply pca to reduce the dimension to one.

df_class = df["class"].copy()
df_numeric = df.select_dtypes(["int64","float64"])

pca = PCA(1)
df_pca = pd.DataFrame(pca.fit_transform(df_numeric), columns=["pc1"])
df_pca.head()
# Out:
#         pc1
# 0  0.722069
# 1  0.811347
# 2 -1.008801
# 3  0.509578
# 4 -0.692037

# %%
# Add the 'class' and 'observation no' properties to the new data frame.

df_pca["class"] = df_class
df_pca["observation_no"] = df_pca.index

# %%
# Plot the 'observation no' versus 'component 1'

plt.figure(figsize=(6,6))
sns.scatterplot(x = "observation_no", y = "pc1", hue="class", data=df_pca);

# %% [markdown]
# ### b) Apply MDS and Visualize (at least two different similarity measures)

# %%
# MDS with Euclidean Distance
mds = MDS(n_components = 1, n_jobs=-1, dissimilarity="euclidean")
df_mds = pd.DataFrame(mds.fit_transform(df_numeric), columns=["dim1"])

df_mds["class"] = df_class
df_mds["observation_no"] = df_mds.index
plt.figure(figsize=(6,6))
sns.scatterplot(x= "observation_no", y= "dim1", hue="class", data=df_mds);

# %%
# MDS with Manhattan Distance
d_matrix = distance_matrix(df_numeric, df_numeric, p=1) # Create a distance matrix using manhattan distance

mds_2 = MDS(n_components = 1, n_jobs=-1, dissimilarity="precomputed")
df_mds_2 = pd.DataFrame(mds_2.fit_transform(d_matrix), columns=["dim1"])

df_mds_2["class"] = df_class
df_mds_2["observation_no"] = df_mds_2.index
plt.figure(figsize=(6,6))
sns.scatterplot(x= "observation_no", y= "dim1", hue="class", data=df_mds_2);

# %% [markdown]
# ### c)

# %% [markdown]
# ##### 1. When PCA is used, observations in the new dimension look like they are projected to the y axis on the original space. That makes sense, because by a quick observation, it looks like the highest variance is around that axis.
#
# ##### 2. MDS gives a somewhat similar result, however the classes are now more distinct. This is because MDS takes the distances between the observations into account and it is obvious that observations that have the same classes are closer to each other than the other class observations. (There are different clusters of observations within the same class as well)
#
# ##### 3. MDS and PCA gives similar results (actually PCA is like a more basic version of the MDS) but MDS is better at preserving the clusters (due to the taking the distance into account).

# %% [markdown]
# ### d)

# %%
df_copy = df.copy()
df_copy["X1sq"] = df["X1"]*df["X1"]
df_copy["X2sq"] = df["X2"]*df["X2"]
df_copy["X1timesX2"] = df["X1"]*df["X2"]

df_copy.head()
# Out:
#          X1        X2 class      X1sq      X2sq  X1timesX2
# 0  0.569483  0.822003     a  0.324311  0.675689   0.468117
# 1  0.411469  0.911424     a  0.169307  0.830693   0.375023
# 2  0.417385 -0.908730     a  0.174210  0.825790  -0.379290
# 3 -0.791828  0.610745     a  0.626991  0.373009  -0.483604
# 4 -0.806777 -0.590857     a  0.650889  0.349111   0.476689

# %%
df_class = df_copy["class"]
df_copy.drop(["class"],axis=1, inplace=True)

pca2 = PCA(n_components = 5)
df2_pca = pd.DataFrame(pca2.fit_transform(df_copy), columns=["pc1", "pc2", "pc3", "pc4", "pc5"])
df2_pca["class"] = df_class

# %%
df_copy.head(1)
# Out:
#          X1        X2      X1sq      X2sq  X1timesX2
# 0  0.569483  0.822003  0.324311  0.675689   0.468117

# %%
# Eigenvalues, they refer to the variance explained on the corresponding component.
pca2.explained_variance_
# Out:
# array([2.49086525, 1.44256642, 1.28808119, 0.54559809, 0.30619998])

# %%
# These are the percentages of these variances explained.
pca2.explained_variance_ratio_
# Out:
# array([0.410133  , 0.23752553, 0.21208879, 0.08983536, 0.05041731])

# %%
# Eigenvectors, vectors that indicate how much contribution is done to the components by each original feature.
pca2.components_
# Out:
# array([[ 0.07766657,  0.71257596, -0.19184503,  0.66582496, -0.07794878],
#        [-0.42317217, -0.07426701,  0.15328013,  0.27219612,  0.84724507],
#        [ 0.21930469, -0.6092683 ,  0.27145989,  0.67993125, -0.21142519],
#        [-0.73210164,  0.13942364,  0.49110581,  0.0249689 , -0.45031087],
#        [ 0.4804434 ,  0.30995661,  0.79045892, -0.14020145,  0.16917239]])

# %% [markdown]
# ### First component, which is mostly a linear combination of X2 and X2squared, explains 41% of the variance in the data.
# ### Second component, which is mostly a linear combination of (-X1) and X1*X2, explains 24% of the variance in the data.

# %% [markdown]
# # Task 2

# %%
# Read the Intercity Distance Data from the xls file

turkey_dist = pd.read_excel("HW2-data/ilmesafe.xls", header=2, index_col=1)
df_tr = turkey_dist.copy()
df_tr = df_tr.fillna(0)
plakalar = df_tr.drop(["İL PLAKA NO"], inplace=True, axis=1)
df_tr = np.maximum(df_tr, df_tr.T) # Convert the matrix to a symmetric one by taking the index-wise maximums of the matrix
# and it's transpose.
city_names = df_tr.index
df_tr.head()
# Out:
#                 ADANA  ADIYAMAN  AFYONKARAHİSAR    AĞRI  AMASYA  ANKARA  \
# ADANA             0.0     335.0           575.0   966.0   603.0   567.0
# ADIYAMAN        335.0       0.0           910.0   648.0   632.0   814.0
# AFYONKARAHİSAR  575.0     910.0             0.0  1318.0   597.0   300.0
# AĞRI            966.0     648.0          1318.0     0.0   738.0  1141.0
# AMASYA          603.0     632.0           597.0   738.0     0.0   413.0
#
#                 ANTALYA  ARTVİN   AYDIN  BALIKESİR  ...  BATMAN  ŞIRNAK  \
# ADANA             535.0  1035.0   874.0      903.0  ...   621.0   709.0
# ADIYAMAN          870.0   751.0  1209.0     1238.0  ...   303.0   471.0
# AFYONKARAHİSAR    291.0  1243.0   345.0      328.0  ...  1196.0  1284.0
# AĞRI             1428.0   396.0  1640.0     1569.0  ...   369.0   430.0
# AMASYA            825.0   695.0   938.0      831.0  ...   796.0   982.0
#
#                 BARTIN  ARDAHAN   IĞDIR  YALOVA  KARABÜK  KİLİS  OSMANİYE  \
# ADANA            782.0   1042.0  1069.0   899.0    714.0  246.0      87.0
# ADIYAMAN        1028.0    758.0   751.0  1152.0    960.0  210.0     248.0
# AFYONKARAHİSAR   515.0   1351.0  1461.0   338.0    447.0  821.0     662.0
# AĞRI            1175.0    310.0   143.0  1363.0   1106.0  814.0     879.0
# AMASYA           437.0    783.0   881.0   625.0    368.0  644.0     613.0
#
#                  DÜZCE
# ADANA            735.0
# ADIYAMAN         981.0
# AFYONKARAHİSAR   375.0
# AĞRI            1192.0
# AMASYA           454.0
#
# [5 rows x 81 columns]

# %%
# Define a function that plots data points and their labels
# src: "https://stackoverflow.com/a/60976733". Made some adjustments such as changing the text weight and size.

def scatter_text(x, y, text_column, data, title, xlabel, ylabel):
    """Scatter plot with country codes on the x y coordinates
       Based on this answer: https://stackoverflow.com/a/54789170/2641825"""
    # Create the scatter plot
    p1 = sns.scatterplot(x=x, y=y, data=data, size = 8, legend=False)
    # Add text besides each point
    for line in range(0,data.shape[0]):
         p1.text(data[x][line]+0.01, data[y][line], 
                 data[text_column][line], horizontalalignment='left', 
                 size='small', color='black', weight='light',
                 
                )
    
    # Set title and axis labels
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    return p1

# %%
#Apply MDS to the distance data (Therefore, no distance transformation is required)

mds = MDS(n_components = 2, n_jobs=-1, dissimilarity="precomputed")
df_tr_mds = pd.DataFrame(mds.fit_transform(df_tr), columns=["h","v"])

# Add the 'plaka' and city names information to the transformed data
df_tr_mds["plaka"] = plakalar
df_tr_mds["city_name"] = city_names

# Plot the data with labels using the function defined above

plt.figure(figsize=(12,6))
scatter_text("h","v","city_name",df_tr_mds,"MDS for Turkey","pc1","pc2");

# %% [markdown]
# ### No unusual observation is seen. It looks exactly like the Turkey map and it looks beautiful :)

# %% [markdown]
# # Task 3

# %%
# X Train
gesture_x_train = pd.read_csv("HW2-data/uWaveGestureLibrary_X_TRAIN", header=None, sep=" ",
                             prefix="t", skipinitialspace=True)
gesture_x_train.rename(columns={"t0":"class"}, inplace=True)
gesture_x_train["class"] = gesture_x_train["class"].astype("int").astype("category")
gesture_x_train.head(4)
# Out:
#   class        t1        t2        t3        t4        t5        t6        t7  \
# 0     6 -0.304243 -0.304243 -0.304243 -0.304243 -0.304243 -0.304243 -0.304243
# 1     5  1.627311  1.627311  1.627311  1.627311  1.627311  1.627311  1.627311
# 2     5  0.661277  0.661277  0.661277  0.661277  0.661277  0.661277  0.661277
# 3     3  0.005185  0.005185  0.005185  0.005185  0.005185  0.005185  0.005185
#
#          t8        t9  ...      t306      t307      t308      t309      t310  \
# 0 -0.304243 -0.304243  ... -0.796414 -0.741728 -0.694698 -0.647669 -0.647669
# 1  1.627311  1.627311  ... -0.237634 -0.237634 -0.237634 -0.237634 -0.237634
# 2  0.661277  0.661277  ... -0.282011 -0.236929 -0.191848 -0.146766 -0.101685
# 3  0.005185  0.005185  ...  1.207290  1.147822  1.094344  1.060362  1.053158
#
#        t311      t312      t313      t314      t315
# 0 -0.647669 -0.647669 -0.647669 -0.647669 -0.647669
# 1 -0.237634 -0.237634 -0.237634 -0.237634 -0.237634
# 2 -0.061203 -0.056638 -0.055462 -0.055462 -0.055462
# 3  1.044467  1.018981  0.909949  0.791013  0.672077
#
# [4 rows x 316 columns]

# %%
# Y Train
gesture_y_train = pd.read_csv("HW2-data/uWaveGestureLibrary_Y_TRAIN", header=None, sep=" ",
                             prefix="t", skipinitialspace=True)
gesture_y_train.rename(columns={"t0":"class"}, inplace=True)
gesture_y_train["class"] = gesture_y_train["class"].astype("int").astype("category")
gesture_y_train.head(4)
# Out:
#   class        t1        t2        t3        t4        t5        t6        t7  \
# 0     6 -2.119396 -2.119396 -2.119396 -2.119396 -2.119396 -2.119396 -2.119396
# 1     5  0.666624  0.666624  0.666624  0.666624  0.666624  0.666624  0.666624
# 2     5 -0.189730 -0.189730 -0.189730 -0.189730 -0.189730 -0.189730 -0.189730
# 3     3  0.374067  0.374067  0.374067  0.374067  0.374067  0.374067  0.374067
#
#          t8        t9  ...      t306      t307      t308      t309      t310  \
# 0 -2.119396 -2.119396  ...  0.084123  0.084123  0.084123  0.084123  0.084123
# 1  0.666624  0.666624  ... -1.517261 -1.554968 -1.592674 -1.629870 -1.662524
# 2 -0.189730 -0.189730  ... -1.492490 -1.492490 -1.492490 -1.492490 -1.492490
# 3  0.374067  0.374067  ... -1.531698 -1.639404 -1.747843 -1.837563 -1.901574
#
#        t311      t312      t313      t314      t315
# 0  0.084123  0.084123  0.084123  0.084123  0.084123
# 1 -1.662524 -1.662524 -1.662524 -1.662524 -1.662524
# 2 -1.492490 -1.492490 -1.492490 -1.492490 -1.492490
# 3 -1.933636 -1.917323 -1.660378 -1.374903 -1.089428
#
# [4 rows x 316 columns]

# %%
# Z Train
gesture_z_train = pd.read_csv("HW2-data/uWaveGestureLibrary_Z_TRAIN", header=None, sep=" ",
                             prefix="t", skipinitialspace=True)
gesture_z_train.rename(columns={"t0":"class"}, inplace=True)
gesture_z_train["class"] = gesture_z_train["class"].astype("int").astype("category")
gesture_z_train.head(4)
# Out:
#   class        t1        t2        t3        t4        t5        t6        t7  \
# 0     6 -1.528965 -1.528965 -1.528965 -1.528965 -1.528965 -1.528965 -1.528965
# 1     5  1.786869  1.786869  1.786869  1.786869  1.786869  1.786869  1.786869
# 2     5  0.521249  0.521249  0.521249  0.521249  0.521249  0.521249  0.521249
# 3     3  0.309455  0.309455  0.309455  0.309455  0.309455  0.309455  0.309455
#
#          t8        t9  ...      t306      t307      t308      t309      t310  \
# 0 -1.528965 -1.528965  ...  0.523217  0.513994  0.503481  0.492967  0.474522
# 1  1.786869  1.786869  ... -0.427010 -0.427010 -0.427010 -0.427172 -0.428773
# 2  0.521249  0.521249  ... -0.862717 -0.862717 -0.862717 -0.862717 -0.862717
# 3  0.309455  0.309455  ... -0.187384 -0.123549 -0.055870  0.011808  0.079487
#
#        t311      t312      t313      t314      t315
# 0  0.456077  0.437632  0.419187  0.400743  0.382298
# 1 -0.440720 -0.452667 -0.464613 -0.476560 -0.488507
# 2 -0.862717 -0.862717 -0.862717 -0.862717 -0.862717
# 3  0.157056  0.253740  0.445503  0.648538  0.851573
#
# [4 rows x 316 columns]

# %% [markdown]
# # a)

# %% [markdown]
# ### Explanations is done only for the first class. Same procedure is followed for the other classes.

# %% [markdown]
# ### Big yellow dots represent the starting point (t=0).

# %%
# Class 1 visualization

# Select the first observation in the data that belongs to the Class 1, for each axis
class1_x = gesture_x_train.drop(["class"],axis=1).loc[10]
class1_y = gesture_y_train.drop(["class"],axis=1).loc[10]
class1_z = gesture_z_train.drop(["class"],axis=1).loc[10]

# Concatenate axes and indicate the initial point

class1_concat = pd.concat([class1_x, class1_y, class1_z], axis=1)
class1_concat.columns = ["x","y","z"]
class1_concat["first"] = (class1_concat.index=="t1").astype(int)


# visualize axes and discriminate the initial point by setting it's size and color differently

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(class1_concat["x"], class1_concat["y"], class1_concat["z"], cmap="cividis" , c=class1_concat["first"], s=class1_concat["first"]*100+20);

# %%
# class 2 visualization

class1_x = gesture_x_train.drop(["class"],axis=1).loc[14]
class1_y = gesture_y_train.drop(["class"],axis=1).loc[14]
class1_z = gesture_z_train.drop(["class"],axis=1).loc[14]

# concatenate axes

class1_concat = pd.concat([class1_x, class1_y, class1_z], axis=1)
class1_concat.columns = ["x","y","z"]
class1_concat["first"] = (class1_concat.index=="t1").astype(int)


# visualize axes

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(class1_concat["x"], class1_concat["y"], class1_concat["z"], cmap="cividis" , c=class1_concat["first"], s=class1_concat["first"]*100+20);

# %%
# class 3 visualization

class1_x = gesture_x_train.drop(["class"],axis=1).loc[3]
class1_y = gesture_y_train.drop(["class"],axis=1).loc[3]
class1_z = gesture_z_train.drop(["class"],axis=1).loc[3]

# concatenate axes

class1_concat = pd.concat([class1_x, class1_y, class1_z], axis=1)
class1_concat.columns = ["x","y","z"]
class1_concat["first"] = (class1_concat.index=="t1").astype(int)


# visualize axes

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(class1_concat["x"], class1_concat["y"], class1_concat["z"], cmap="cividis" , c=class1_concat["first"], s=class1_concat["first"]*100+20);

# %%
# class 4 visualization

class1_x = gesture_x_train.drop(["class"],axis=1).loc[4]
class1_y = gesture_y_train.drop(["class"],axis=1).loc[4]
class1_z = gesture_z_train.drop(["class"],axis=1).loc[4]

# concatenate axes

class1_concat = pd.concat([class1_x, class1_y, class1_z], axis=1)
class1_concat.columns = ["x","y","z"]
class1_concat["first"] = (class1_concat.index=="t1").astype(int)


# visualize axes

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(class1_concat["x"], class1_concat["y"], class1_concat["z"], cmap="cividis" , c=class1_concat["first"], s=class1_concat["first"]*100+20);

# %%
# class 5 visualization

class1_x = gesture_x_train.drop(["class"],axis=1).loc[1]
class1_y = gesture_y_train.drop(["class"],axis=1).loc[1]
class1_z = gesture_z_train.drop(["class"],axis=1).loc[1]

# concatenate axes

class1_concat = pd.concat([class1_x, class1_y, class1_z], axis=1)
class1_concat.columns = ["x","y","z"]
class1_concat["first"] = (class1_concat.index=="t1").astype(int)


# visualize axes

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(class1_concat["x"], class1_concat["y"], class1_concat["z"], cmap="cividis" , c=class1_concat["first"], s=class1_concat["first"]*100+20);

# %%
# class 6 visualization

class1_x = gesture_x_train.drop(["class"],axis=1).loc[0]
class1_y = gesture_y_train.drop(["class"],axis=1).loc[0]
class1_z = gesture_z_train.drop(["class"],axis=1).loc[0]

# concatenate axes

class1_concat = pd.concat([class1_x, class1_y, class1_z], axis=1)
class1_concat.columns = ["x","y","z"]
class1_concat["first"] = (class1_concat.index=="t1").astype(int)


# visualize axes

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(class1_concat["x"], class1_concat["y"], class1_concat["z"], cmap="cividis" , c=class1_concat["first"], s=class1_concat["first"]*100+20);

# %%
# class 7 visualization

class1_x = gesture_x_train.drop(["class"],axis=1).loc[6]
class1_y = gesture_y_train.drop(["class"],axis=1).loc[6]
class1_z = gesture_z_train.drop(["class"],axis=1).loc[6]

# concatenate axes

class1_concat = pd.concat([class1_x, class1_y, class1_z], axis=1)
class1_concat.columns = ["x","y","z"]
class1_concat["first"] = (class1_concat.index=="t1").astype(int)


# visualize axes

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(class1_concat["x"], class1_concat["y"], class1_concat["z"], cmap="cividis" , c=class1_concat["first"], s=class1_concat["first"]*100+20);

# %%
# class 8 visualization

class1_x = gesture_x_train.drop(["class"],axis=1).loc[5]
class1_y = gesture_y_train.drop(["class"],axis=1).loc[5]
class1_z = gesture_z_train.drop(["class"],axis=1).loc[5]

# concatenate axes

class1_concat = pd.concat([class1_x, class1_y, class1_z], axis=1)
class1_concat.columns = ["x","y","z"]
class1_concat["first"] = (class1_concat.index=="t1").astype(int)


# visualize axes

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(class1_concat["x"], class1_concat["y"], class1_concat["z"], cmap="cividis" , c=class1_concat["first"], s=class1_concat["first"]*100+20);

# %% [markdown]
# ### b)

# %%
# X Train
gesture_x_train_b = pd.read_csv("HW2-data/uWaveGestureLibrary_X_TRAIN", header=None, sep=" ",
                             prefix="xt", skipinitialspace=True)
gesture_x_train_b.rename(columns={"xt0":"class"}, inplace=True)
gesture_x_train_b["class"] = gesture_x_train_b["class"].astype("int").astype("category")

# Y Train
gesture_y_train_b = pd.read_csv("HW2-data/uWaveGestureLibrary_Y_TRAIN", header=None, sep=" ",
                             prefix="yt", skipinitialspace=True)
gesture_y_train_b.rename(columns={"yt0":"class"}, inplace=True)
gesture_y_train_b["class"] = gesture_y_train_b["class"].astype("int").astype("category")
gesture_y_train_b.drop(["class"], axis=1, inplace=True)

# Z Train
gesture_z_train_b = pd.read_csv("HW2-data/uWaveGestureLibrary_Z_TRAIN", header=None, sep=" ",
                             prefix="zt", skipinitialspace=True)
gesture_z_train_b.rename(columns={"zt0":"class"}, inplace=True)
gesture_z_train_b["class"] = gesture_z_train_b["class"].astype("int").astype("category")
gesture_z_train_b.drop(["class"], axis=1, inplace=True)

# %%
# concatenate the variables
concat_gesture_b = pd.concat([gesture_x_train_b, gesture_y_train_b, gesture_z_train_b], join="inner", axis=1)
concat_gesture_b.head()
# Out:
#   class       xt1       xt2       xt3       xt4       xt5       xt6       xt7  \
# 0     6 -0.304243 -0.304243 -0.304243 -0.304243 -0.304243 -0.304243 -0.304243
# 1     5  1.627311  1.627311  1.627311  1.627311  1.627311  1.627311  1.627311
# 2     5  0.661277  0.661277  0.661277  0.661277  0.661277  0.661277  0.661277
# 3     3  0.005185  0.005185  0.005185  0.005185  0.005185  0.005185  0.005185
# 4     4  1.286198  1.286198  1.286198  1.286198  1.286198  1.286198  1.286198
#
#         xt8       xt9  ...     zt306     zt307     zt308     zt309     zt310  \
# 0 -0.304243 -0.304243  ...  0.523217  0.513994  0.503481  0.492967  0.474522
# 1  1.627311  1.627311  ... -0.427010 -0.427010 -0.427010 -0.427172 -0.428773
# 2  0.661277  0.661277  ... -0.862717 -0.862717 -0.862717 -0.862717 -0.862717
# 3  0.005185  0.005185  ... -0.187384 -0.123549 -0.055870  0.011808  0.079487
# 4  1.286198  1.286198  ...  1.867473  1.834319  1.756000  1.638582  1.521164
#
#       zt311     zt312     zt313     zt314     zt315
# 0  0.456077  0.437632  0.419187  0.400743  0.382298
# 1 -0.440720 -0.452667 -0.464613 -0.476560 -0.488507
# 2 -0.862717 -0.862717 -0.862717 -0.862717 -0.862717
# 3  0.157056  0.253740  0.445503  0.648538  0.851573
# 4  1.453266  1.515219  1.632637  1.750054  1.867473
#
# [5 rows x 946 columns]

# %%
concat_class1 = concat_gesture_b[concat_gesture_b["class"]==1].drop(["class"], axis=1)
concat_class2 = concat_gesture_b[concat_gesture_b["class"]==2].drop(["class"], axis=1)
concat_class3 = concat_gesture_b[concat_gesture_b["class"]==3].drop(["class"], axis=1)
concat_class4 = concat_gesture_b[concat_gesture_b["class"]==4].drop(["class"], axis=1)
concat_class5 = concat_gesture_b[concat_gesture_b["class"]==5].drop(["class"], axis=1)
concat_class6 = concat_gesture_b[concat_gesture_b["class"]==6].drop(["class"], axis=1)
concat_class7 = concat_gesture_b[concat_gesture_b["class"]==7].drop(["class"], axis=1)
concat_class8 = concat_gesture_b[concat_gesture_b["class"]==8].drop(["class"], axis=1)

# %% [markdown]
# ### For the part a and part b, each step is explained only for Class 1. It is a repetitive task and the exact same
# ### steps are followed for the other classes as well.

# %% [markdown]
# # Class 1)

# %%
# Let's observe the first 5 observations for the Class 1 gestures.
concat_class1.head()
# Out:
#          xt1       xt2       xt3       xt4       xt5       xt6       xt7  \
# 10 -0.791447 -0.791447 -0.795873 -0.810065 -0.849230 -0.903465 -0.931146
# 16 -0.449602 -0.449602 -0.449602 -0.449602 -0.449602 -0.449602 -0.449602
# 18 -0.187469 -0.187469 -0.187469 -0.187469 -0.187469 -0.187469 -0.187469
# 22  0.301482  0.301482  0.301482  0.301482  0.301482  0.301482  0.301482
# 37  0.163202  0.163202  0.163202  0.163202  0.163202  0.163202  0.163202
#
#          xt8       xt9      xt10  ...     zt306     zt307     zt308     zt309  \
# 10 -0.950603 -0.950603 -0.950603  ... -0.007064  0.005636  0.005636  0.005636
# 16 -0.449602 -0.449602 -0.449602  ...  0.818899  0.836256  0.843713  0.843713
# 18 -0.187469 -0.187469 -0.187469  ...  0.251094  0.272352  0.285509  0.298453
# 22  0.301482  0.301482  0.301482  ...  0.046818  0.046818  0.046818  0.046142
# 37  0.163202  0.163202  0.163202  ...  0.684985  0.678933  0.657091  0.610350
#
#        zt310     zt311     zt312     zt313     zt314     zt315
# 10  0.005636  0.005636  0.005636  0.005636  0.005636  0.005636
# 16  0.865130  0.894524  0.928201  0.961878  0.995555  1.029232
# 18  0.310528  0.321015  0.321015  0.321015  0.321015  0.321015
# 22  0.042720  0.038071  0.025332  0.012593 -0.000146 -0.012885
# 37  0.563609  0.516868  0.470127  0.423385  0.376644  0.329903
#
# [5 rows x 945 columns]

# %%
# Matrix is tansposed in order to apply PCA by taking each observation as a feature. After that, new data with two principal
# components is printed.

rows = concat_class1.columns
class1_observations = concat_class1.index
concat_class1_T = concat_class1.T
pca_class1 = PCA(2)
reduced_class1 = pd.DataFrame(pca_class1.fit_transform(concat_class1_T), index=rows, columns=["cmp1","cmp2"])
reduced_class1.head()
# Out:
#          cmp1      cmp2
# xt1 -3.688900 -5.182183
# xt2 -3.687540 -5.163230
# xt3 -3.692586 -5.144571
# xt4 -3.696911 -5.131040
# xt5 -3.697124 -5.124149

# %% [markdown]
# # a)

# %%
# Calling the explained_variance_ratio_ attribute of the PCA object.
pca_class1.explained_variance_ratio_
# Out:
# array([0.52997902, 0.10401207])

# %% [markdown]
# ### 63% of the variance is recevored from the first two component.

# %% [markdown]
# # b)

# %%
# Calling the eigenvectors of the PCA with the 'components_' attribute and presenting them with their corresponding component
# and showing how much contribution each observation does to each component.
class1_eigenvectors = pd.DataFrame(pca_class1.components_, index=["cmp1","cmp2"], columns=class1_observations)
class1_eigenvectors
# Out:
#            10        16        18        22        37        42        45   \
# cmp1  0.075076  0.096553  0.096187  0.084469  0.096703  0.105346  0.023688
# cmp2  0.152411  0.076145 -0.045665 -0.114565 -0.074084  0.102036  0.018359
#
#            48        53        55   ...       835       845       847  \
# cmp1  0.099499  0.102839  0.092903  ...  0.075253  0.103435  0.110164
# cmp2  0.027438 -0.033870  0.024883  ... -0.050588 -0.098555 -0.048144
#
#            854       856       865       878       883       885       892
# cmp1  0.044813  0.079647  0.067044  0.062802  0.110183  0.110166  0.087095
# cmp2  0.204167  0.103542 -0.030223 -0.169714  0.055826  0.013741  0.146706
#
# [2 rows x 122 columns]

# %%
sns.lineplot(x=class1_eigenvectors.columns, y= class1_eigenvectors.iloc[0], color='r')
sns.lineplot(x=class1_eigenvectors.columns, y= class1_eigenvectors.iloc[1], color='g');

# %% [markdown]
# ### Eigenvectors imply the contribution of the each observation to the corresponding component.

# %% [markdown]
# # Class 2)

# %%
rows = concat_class2.columns
class2_observations = concat_class2.index
concat_class2_T = concat_class2.T
pca_class2 = PCA(2)
reduced_class2 = pd.DataFrame(pca_class2.fit_transform(concat_class2_T), index=rows, columns=["cmp1","cmp2"])

pca_class2.explained_variance_ratio_
# Out:
# array([0.52712574, 0.15491441])

# %% [markdown]
# ### 68% of the variance is recevored from the first two component.

# %%
class2_eigenvectors = pd.DataFrame(pca_class2.components_, index=["cmp1","cmp2"], columns=class2_observations)

sns.lineplot(x=class2_eigenvectors.columns, y= class2_eigenvectors.iloc[0], color='r')
sns.lineplot(x=class2_eigenvectors.columns, y= class2_eigenvectors.iloc[1], color='g');

# %% [markdown]
# # Class 3)

# %%
rows = concat_class3.columns
class3_observations = concat_class3.index
concat_class3_T = concat_class3.T
pca_class3 = PCA(2)
reduced_class3 = pd.DataFrame(pca_class3.fit_transform(concat_class3_T), index=rows, columns=["cmp1","cmp2"])

pca_class3.explained_variance_ratio_
# Out:
# array([0.41132921, 0.18358206])

# %% [markdown]
# ### 59% of the variance is recevored from the first two component.

# %%
class3_eigenvectors = pd.DataFrame(pca_class3.components_, index=["cmp1","cmp2"], columns=class3_observations)

sns.lineplot(x=class3_eigenvectors.columns, y= class3_eigenvectors.iloc[0], color='r')
sns.lineplot(x=class3_eigenvectors.columns, y= class3_eigenvectors.iloc[1], color='g');

# %% [markdown]
# # Class 4)

# %%
rows = concat_class4.columns
class4_observations = concat_class4.index
concat_class4_T = concat_class4.T
pca_class4 = PCA(2)
reduced_class4 = pd.DataFrame(pca_class4.fit_transform(concat_class4_T), index=rows, columns=["cmp1","cmp2"])

pca_class4.explained_variance_ratio_
# Out:
# array([0.41372499, 0.13175833])

# %% [markdown]
# ### 54% of the variance is recevored from the first two component.

# %%
class4_eigenvectors = pd.DataFrame(pca_class4.components_, index=["cmp1","cmp2"], columns=class4_observations)

sns.lineplot(x=class4_eigenvectors.columns, y= class4_eigenvectors.iloc[0], color='r')
sns.lineplot(x=class4_eigenvectors.columns, y= class4_eigenvectors.iloc[1], color='g');

# %% [markdown]
# # Class 5)

# %%
rows = concat_class5.columns
class5_observations = concat_class5.index
concat_class5_T = concat_class5.T
pca_class5 = PCA(2)
reduced_class5 = pd.DataFrame(pca_class5.fit_transform(concat_class5_T), index=rows, columns=["cmp1","cmp2"])

pca_class5.explained_variance_ratio_
# Out:
# array([0.52631191, 0.12721762])

# %% [markdown]
# ### 65% of the variance is recevored from the first two component.

# %%
class5_eigenvectors = pd.DataFrame(pca_class5.components_, index=["cmp1","cmp2"], columns=class5_observations)

sns.lineplot(x=class5_eigenvectors.columns, y= class5_eigenvectors.iloc[0], color='r')
sns.lineplot(x=class5_eigenvectors.columns, y= class5_eigenvectors.iloc[1], color='g');

# %% [markdown]
# # Class 6)

# %%
rows = concat_class6.columns
class6_observations = concat_class6.index
concat_class6_T = concat_class6.T
pca_class6 = PCA(2)
reduced_class6 = pd.DataFrame(pca_class6.fit_transform(concat_class6_T), index=rows, columns=["cmp1","cmp2"])

pca_class6.explained_variance_ratio_
# Out:
# array([0.42327801, 0.11671467])

# %% [markdown]
# ### 54% of the variance is recevored from the first two component.

# %%
class6_eigenvectors = pd.DataFrame(pca_class6.components_, index=["cmp1","cmp2"], columns=class6_observations)

sns.lineplot(x=class6_eigenvectors.columns, y= class6_eigenvectors.iloc[0], color='r')
sns.lineplot(x=class6_eigenvectors.columns, y= class6_eigenvectors.iloc[1], color='g');

# %% [markdown]
# # Class 7)

# %%
rows = concat_class7.columns
class7_observations = concat_class7.index
concat_class7_T = concat_class7.T
pca_class7 = PCA(2)
reduced_class7 = pd.DataFrame(pca_class7.fit_transform(concat_class7_T), index=rows, columns=["cmp1","cmp2"])

pca_class7.explained_variance_ratio_
# Out:
# array([0.49705099, 0.16381657])

# %% [markdown]
# ### 66% of the variance is recevored from the first two component.

# %%
class7_eigenvectors = pd.DataFrame(pca_class7.components_, index=["cmp1","cmp2"], columns=class7_observations)

sns.lineplot(x=class7_eigenvectors.columns, y= class7_eigenvectors.iloc[0], color='r')
sns.lineplot(x=class7_eigenvectors.columns, y= class7_eigenvectors.iloc[1], color='g');

# %% [markdown]
# # Class 8)

# %%
rows = concat_class8.columns
class8_observations = concat_class8.index
concat_class8_T = concat_class8.T
pca_class8 = PCA(2)
reduced_class8 = pd.DataFrame(pca_class8.fit_transform(concat_class8_T), index=rows, columns=["cmp1","cmp2"])

pca_class8.explained_variance_ratio_
# Out:
# array([0.4774311 , 0.26678782])

# %% [markdown]
# ### 74% of the variance is recevored from the first two component.

# %%
class8_eigenvectors = pd.DataFrame(pca_class8.components_, index=["cmp1","cmp2"], columns=class8_observations)

sns.lineplot(x=class8_eigenvectors.columns, y= class8_eigenvectors.iloc[0], color='r')
sns.lineplot(x=class8_eigenvectors.columns, y= class8_eigenvectors.iloc[1], color='g');

# %% [markdown]
# ## Comments:

# %% [markdown]
# ### In general, component with the higher eigenvalue(which explaince more variance) gets similar contribution from each observation (similar coefficients). This means that each observation is equally important to explain the most of the variance in the data.
#
# ### For the other component, for some reason, contribution of each observation differs drastically.

# %%
# This line is used to create html version of the notebook.

import os

os.system('jupyter nbconvert --to html HW2.ipynb')
# Out:
# 0
